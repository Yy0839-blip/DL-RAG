# %%
# LlamaIndex로 연결할 Cohere / PDF Reader 설치
# !pip install llama-index-llms-cohere
# !pip install llama-index-embeddings-cohere
# !pip install llama-index-readers-file
# !pip install pypdf

# %% [markdown]
# Cohear api key
#
# 트라이얼 키 :
# Set COHERE_API_KEY in your environment before running the notebook.

# %%
from llama_index.llms.cohere import Cohere
from llama_index.embeddings.cohere import CohereEmbedding
from llama_index.core import Settings, VectorStoreIndex, SimpleDirectoryReader
from llama_index.readers.file import PDFReader
import os
# Out:
# 2026-04-28 11:20:36,494 - INFO - NumExpr defaulting to 10 threads.

# %%
# Cohere LLM/Embedding 모델 사용 설정
cohere_api_key = os.environ["COHERE_API_KEY"]

llm = Cohere(
    model = 'command-r7b-12-2024',
    api_key = cohere_api_key,
    temperature = 0
)

embed_model = CohereEmbedding(
    api_key = cohere_api_key,
    model_name = 'embed-multilingual-v3.0',
    input_type = 'search_document'
)

Settings.llm = llm
Settings.embed_model = embed_model

print('Cohere 설정 완료')
# Out:
# Cohere 설정 완료

# %%
documents = SimpleDirectoryReader(
    input_dir = "../Data/pdf_sample1",
    file_extractor = {".pdf" : PDFReader()}
).load_data()

# %%
print(f'로드된 문서 수 : {len(documents)}')
# Out:
# 로드된 문서 수 : 24

# %%
print(documents[0])
# Out:
# Doc ID: 14620c66-224a-4d81-ab5b-5d5b0cf7a015
# Text: 2024 미국의 인공지능(AI) 정책․전략 현황과 변화 방향     - AI 지배력 강화와 초강대국 유지를 위해
# 미국은 어떻게 변화하고 있는가?-

# %%
index = VectorStoreIndex.from_documents(documents)
# Out:
# 2026-04-28 11:20:42,316 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:20:42,732 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:20:43,122 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:20:43,563 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:20:43,982 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:20:44,388 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:20:44,758 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:20:45,167 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:20:46,216 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# ...

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("미국의 인공지능 정책과 주요 변화를 한국어로 설명해주세요")
# Out:
# 2026-04-28 11:00:47,872 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:00:52,669 - INFO - HTTP Request: POST https://api.cohere.com/v1/chat "HTTP/1.1 200 OK"

# %%
print(response)
# Out:
# 미국의 인공지능(AI) 정책은 AI 지배력 강화와 초강대국 유지를 위해 변화하고 있습니다. 주요 변화는 다음과 같습니다.
#
# 1. 미 행정부의 변화: AI 경쟁력 확보 및 강화에서 'AI 팍스 아메리카나'로
#
# * 미국 역대 정권은 시장과 기술 우위성을 토대로 막대한 연구개발(R&D) 투자를 확대해 AI 강국의 지위를 더욱 공고히 하고, 세계 최고의 AI 경쟁력을 유지하는 것을 목표로 합니다.
# * 오바마 행정부는 AI R&D 전략을 수립해 연방 정부의 R&D 지원 사항을 정하고, 특히 공중위생이나 안보 등 민간이 다루기 어려운 분야 지원을 중시하는 방침을 명기했습니다.
# * 트럼프 대통령은 '19년 연두 교서 연설에서 미래 첨단 산업 투자의 중요성을 역설하고, AI에 대한 지속적 투자와 정부 기관 R&D 투자에서 AI를 우선하도록 요구하는 등 AI 투자 강화를 강조했습니다.
# * 트럼프 행정부는 경제와 안보에 미치는 AI의 전략적 중요성을 인식하고, AI 연구 투자를 2배로 증액했습니다.
# * 바이든 행정부는 중국의 AI 야심에 위협받고 예상치 못한 AI 위험에 노출되면서 점차 AI 분야 경쟁력 유지와 함께 책임 있는 AI 개발과 이용을 강조하는 방향으로 AI 정책을 전환했습니다.
# * '챗GPT' 공개로 생성AI 서비스가 급속히 보급되면서 가짜 정보 등 AI가 사회에 미치는 부정적 영향을 우려하고, 중국의 AI 기술 경쟁력 강화에 따른 위협에 대응하기 시작했습니다.

# %%
for node in response.source_nodes:
    print(f"score : {node.score}")
    print("-" * 50)
# Out:
# score : 0.6615330397207454
# --------------------------------------------------
# score : 0.6577842529127716
# --------------------------------------------------

# %%
response = query_engine.query("미국의 AI 정책 발표 내용 중 2024년의 주요 내용을 한국어로 설명해주세요")
print(response)
# Out:
# 2026-04-28 11:04:21,403 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:04:27,139 - INFO - HTTP Request: POST https://api.cohere.com/v1/chat "HTTP/1.1 200 OK"
# 2024년 미국의 AI 정책 발표 내용 중 주요 내용은 다음과 같습니다.
#
# 1. **AI 지배력 강화**: 미국은 AI 기술과 산업에서 지배력을 강화하고 초강대국으로서의 입지를 유지하기 위해 노력하고 있습니다. 이를 위해 AI 연구개발, 인재 양성, 규제 개선 등을 추진하고 있습니다.
#
# 2. **AI 관련 법안 및 정책**:
#    - **하원 bipartisan task force on artificial intelligence**: 2024년 2월, 미국 하원은 AI 관련 bipartisan task force를 발족하여 AI 정책 개발과 입법을 지원하고 있습니다.
#    - **AI 관련 법안**: 미국 정부는 AI 관련 법안을 검토하고 있으며, AI 안전성, 윤리, 책임 등에 대한 규제를 강화하는 방안을 고려하고 있습니다.
#
# 3. **AI 기술 개발 및 활용**:
#    - **AI 기술 개발**: 미국 정부는 AI 기술 개발을 지원하고 있으며, 특히 AI 안전성, 윤리, 책임 등에 대한 연구를 강화하고 있습니다.
#    - **AI 활용**: 미국 정부는 AI 기술을 다양한 분야에서 활용하고 있으며, 특히 의료, 교육, 교통 등 사회 전반에 AI 기술을 적용하는 방안을 모색하고 있습니다.
#
# 4. **AI 인재 양성**:
#    - **AI 인재 양성**: 미국 정부는 AI 인재 양성을 위해 교육 프로그램을 강화하고 있으며, 특히 AI 관련 학과와 프로그램을 확대하고 있습니다.
# ...

# %%
response = query_engine.query("미국의 AI 정책 발표 내용 중 의료 분야 지원에 대한 부분도 있나요?")
print(response)
# Out:
# 2026-04-28 11:05:02,898 - INFO - HTTP Request: POST https://api.cohere.com/v2/embed "HTTP/1.1 200 OK"
# 2026-04-28 11:05:04,330 - INFO - HTTP Request: POST https://api.cohere.com/v1/chat "HTTP/1.1 200 OK"
# 네, 미국의 AI 정책 발표 내용 중 의료 분야 지원에 대한 부분이 있습니다.
#
# 정책에서는 의료 분야에 AI를 효율적으로 활용해 저렴하고 생명을 구하는 신약 개발을 촉진하는 내용을 포함하고 있습니다. 또한, 의료 프로그램과 활동에 대한 차별 금지 요건이 AI, 임상 알고리즘, 예측 분석 및 기타 도구의 사용에 계속 적용됨을 명확히 하는 최종 규칙을 발표했습니다.
